# %%
import pandas as pd
from pycaret.clustering import *
import plotly.io as pio
pio.renderers.default = 'iframe'

# %%
reviews = pd.read_csv("tripadvisor_review.csv")
reviews.drop("User ID", axis = 1, inplace = True)
reviews
# Out:
#      Category 1  Category 2  Category 3  Category 4  Category 5  Category 6  \
# 0          0.93        1.80        2.29        0.62        0.80        2.42
# 1          1.02        2.20        2.66        0.64        1.42        3.18
# 2          1.22        0.80        0.54        0.53        0.24        1.54
# 3          0.45        1.80        0.29        0.57        0.46        1.52
# 4          0.51        1.20        1.18        0.57        1.54        2.02
# ..          ...         ...         ...         ...         ...         ...
# 975        0.74        1.12        0.30        0.53        0.88        1.38
# 976        1.25        0.92        1.12        0.38        0.78        1.68
# 977        0.61        1.32        0.67        0.43        1.30        1.78
# 978        0.93        0.20        0.13        0.43        0.30        0.40
# 979        0.93        0.56        1.13        0.51        1.34        2.36
#
#      Category 7  Category 8  Category 9  Category 10
# 0          3.19        2.79        1.82         2.42
# 1          3.21        2.63        1.86         2.32
# 2          3.18        2.80        1.31         2.50
# 3          3.18        2.96        1.57         2.86
# 4          3.18        2.78        1.18         2.54
# ..          ...         ...         ...          ...
# 975        3.17        2.78        0.99         3.20
# 976        3.18        2.79        1.34         2.80
# 977        3.17        2.81        1.34         3.02
# 978        3.18        2.98        1.12         2.46
# 979        3.18        2.87        1.34         2.40
#
# [980 rows x 10 columns]

# %%
ClusteringParameters = setup(reviews)
# Out:
# <style type="text/css">
# #T_036b7_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_036b7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_036b7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_036b7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_036b7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_036b7_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_036b7_row0_col1" class="data row0 col1" >2814</td>
#     </tr>
#     <tr>
#       <th id="T_036b7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_036b7_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_036b7_row1_col1" class="data row1 col1" >(980, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_036b7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_036b7_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_036b7_row2_col1" class="data row2 col1" >(980, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_036b7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_036b7_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_036b7_row3_col1" class="data row3 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_036b7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_036b7_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_036b7_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_036b7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_036b7_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_036b7_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_036b7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_036b7_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_036b7_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_036b7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_036b7_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_036b7_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_036b7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_036b7_row8_col0" class="data row8 col0" >CPU Jobs</td>
#       <td id="T_036b7_row8_col1" class="data row8 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_036b7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_036b7_row9_col0" class="data row9 col0" >Use GPU</td>
#       <td id="T_036b7_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_036b7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_036b7_row10_col0" class="data row10 col0" >Log Experiment</td>
#       <td id="T_036b7_row10_col1" class="data row10 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_036b7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_036b7_row11_col0" class="data row11 col0" >Experiment Name</td>
#       <td id="T_036b7_row11_col1" class="data row11 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_036b7_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_036b7_row12_col0" class="data row12 col0" >USI</td>
#       <td id="T_036b7_row12_col1" class="data row12 col1" >f551</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("For Cluster = 3")
_3clustermodel = create_model('kmeans', num_clusters = 3)
_3clusterprediction = assign_model(_3clustermodel)

print("For Cluster = 4")
_4clustermodel = create_model('kmeans', num_clusters = 4)
_4clusterprediction = assign_model(_4clustermodel)

print("For Cluster = 5")
_5clustermodel = create_model('kmeans', num_clusters = 5)
_5clusterprediction = assign_model(_5clustermodel)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_86a19">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86a19_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_86a19_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_86a19_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_86a19_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_86a19_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_86a19_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86a19_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_86a19_row0_col0" class="data row0 col0" >0.2060</td>
#       <td id="T_86a19_row0_col1" class="data row0 col1" >317.3186</td>
#       <td id="T_86a19_row0_col2" class="data row0 col2" >1.7053</td>
#       <td id="T_86a19_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_86a19_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_86a19_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_4bd9b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4bd9b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_4bd9b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_4bd9b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_4bd9b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_4bd9b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_4bd9b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4bd9b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4bd9b_row0_col0" class="data row0 col0" >0.1721</td>
#       <td id="T_4bd9b_row0_col1" class="data row0 col1" >256.6789</td>
#       <td id="T_4bd9b_row0_col2" class="data row0 col2" >1.6579</td>
#       <td id="T_4bd9b_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_4bd9b_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_4bd9b_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_943e9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_943e9_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_943e9_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_943e9_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_943e9_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_943e9_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_943e9_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_943e9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_943e9_row0_col0" class="data row0 col0" >0.1747</td>
#       <td id="T_943e9_row0_col1" class="data row0 col1" >224.8638</td>
#       <td id="T_943e9_row0_col2" class="data row0 col2" >1.7027</td>
#       <td id="T_943e9_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_943e9_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_943e9_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
_3clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/No_Data_Processing/3clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_4clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/No_Data_Processing/4clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_5clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/No_Data_Processing/5clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='cluster')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_8.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='cluster')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_9.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='cluster')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_10.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
plot_model(_4clustermodel, plot='elbow')

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='silhouette')
# Out:
# For C = 3

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='silhouette')
# Out:
# For C = 4

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='silhouette')
# Out:
# For C = 5

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='distribution')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_15.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='distribution')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_16.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='distribution')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_17.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# <H3>K-Means Using Normalisation</H3>

# %%
ClusteringParameters = setup(data = reviews, normalize = True, normalize_method = 'zscore', verbose=False)

# %%
print("For Cluster = 3")
_3clustermodel = create_model('kmeans', num_clusters = 3)
_3clusterprediction = assign_model(_3clustermodel)

print("For Cluster = 4")
_4clustermodel = create_model('kmeans', num_clusters = 4)
_4clusterprediction = assign_model(_4clustermodel)

print("For Cluster = 5")
_5clustermodel = create_model('kmeans', num_clusters = 5)
_5clusterprediction = assign_model(_5clustermodel)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_defad">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_defad_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_defad_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_defad_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_defad_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_defad_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_defad_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_defad_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_defad_row0_col0" class="data row0 col0" >0.1387</td>
#       <td id="T_defad_row0_col1" class="data row0 col1" >182.6051</td>
#       <td id="T_defad_row0_col2" class="data row0 col2" >2.1286</td>
#       <td id="T_defad_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_defad_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_defad_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_51169">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_51169_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_51169_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_51169_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_51169_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_51169_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_51169_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51169_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_51169_row0_col0" class="data row0 col0" >0.1327</td>
#       <td id="T_51169_row0_col1" class="data row0 col1" >151.6083</td>
#       <td id="T_51169_row0_col2" class="data row0 col2" >2.2078</td>
#       <td id="T_51169_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_51169_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_51169_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_9cebf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9cebf_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9cebf_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9cebf_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9cebf_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9cebf_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9cebf_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9cebf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9cebf_row0_col0" class="data row0 col0" >0.1428</td>
#       <td id="T_9cebf_row0_col1" class="data row0 col1" >139.2345</td>
#       <td id="T_9cebf_row0_col2" class="data row0 col2" >2.0036</td>
#       <td id="T_9cebf_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_9cebf_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_9cebf_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
_3clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/Normalisation/3clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_4clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/Normalisation/4clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_5clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/Normalisation/5clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='cluster')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_23.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='cluster')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_24.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='cluster')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_25.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
plot_model(_4clustermodel, plot='elbow')

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='silhouette')
# Out:
# For C = 3

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='silhouette')
# Out:
# For C = 4

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='silhouette')
# Out:
# For C = 5

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='distribution')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_30.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='distribution')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_31.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='distribution')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_32.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# <H3>K-Means Using Transformation</H3>

# %%
setup(data = reviews, transformation = True, transformation_method = 'yeo-johnson', verbose=False)

# %%
print("For Cluster = 3")
_3clustermodel = create_model('kmeans', num_clusters = 3)
_3clusterprediction = assign_model(_3clustermodel)

print("For Cluster = 4")
_4clustermodel = create_model('kmeans', num_clusters = 4)
_4clusterprediction = assign_model(_4clustermodel)

print("For Cluster = 5")
_5clustermodel = create_model('kmeans', num_clusters = 5)
_5clusterprediction = assign_model(_5clustermodel)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_6b17d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6b17d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6b17d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6b17d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6b17d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6b17d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6b17d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6b17d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6b17d_row0_col0" class="data row0 col0" >0.2464</td>
#       <td id="T_6b17d_row0_col1" class="data row0 col1" >444.7245</td>
#       <td id="T_6b17d_row0_col2" class="data row0 col2" >1.3699</td>
#       <td id="T_6b17d_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_6b17d_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_6b17d_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_faf34">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_faf34_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_faf34_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_faf34_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_faf34_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_faf34_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_faf34_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_faf34_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_faf34_row0_col0" class="data row0 col0" >0.2498</td>
#       <td id="T_faf34_row0_col1" class="data row0 col1" >417.4153</td>
#       <td id="T_faf34_row0_col2" class="data row0 col2" >1.2631</td>
#       <td id="T_faf34_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_faf34_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_faf34_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_556da">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_556da_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_556da_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_556da_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_556da_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_556da_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_556da_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_556da_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_556da_row0_col0" class="data row0 col0" >0.2297</td>
#       <td id="T_556da_row0_col1" class="data row0 col1" >356.7759</td>
#       <td id="T_556da_row0_col2" class="data row0 col2" >1.2990</td>
#       <td id="T_556da_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_556da_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_556da_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
_3clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/Transformation/3clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_4clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/Transformation/4clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_5clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/Transformation/5clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='cluster')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_38.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='cluster')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_39.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='cluster')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_40.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
plot_model(_4clustermodel, plot='elbow')

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='silhouette')
# Out:
# For C = 3

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='silhouette')
# Out:
# For C = 4

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='silhouette')
# Out:
# For C = 5

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='distribution')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_45.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='distribution')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_46.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='distribution')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_47.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# <H3>K-Means using PCA</H3>

# %%
setup(data = reviews, pca = True, pca_method = 'linear', verbose=False)

# %%
print("For Cluster = 3")
_3clustermodel = create_model('kmeans', num_clusters = 3)
_3clusterprediction = assign_model(_3clustermodel)

print("For Cluster = 4")
_4clustermodel = create_model('kmeans', num_clusters = 4)
_4clusterprediction = assign_model(_4clustermodel)

print("For Cluster = 5")
_5clustermodel = create_model('kmeans', num_clusters = 5)
_5clusterprediction = assign_model(_5clustermodel)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_c139b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c139b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_c139b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_c139b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_c139b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_c139b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_c139b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c139b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c139b_row0_col0" class="data row0 col0" >0.2176</td>
#       <td id="T_c139b_row0_col1" class="data row0 col1" >317.2355</td>
#       <td id="T_c139b_row0_col2" class="data row0 col2" >1.6907</td>
#       <td id="T_c139b_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_c139b_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_c139b_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_88a5c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88a5c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_88a5c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_88a5c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_88a5c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_88a5c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_88a5c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88a5c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_88a5c_row0_col0" class="data row0 col0" >0.1953</td>
#       <td id="T_88a5c_row0_col1" class="data row0 col1" >253.9628</td>
#       <td id="T_88a5c_row0_col2" class="data row0 col2" >1.7310</td>
#       <td id="T_88a5c_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_88a5c_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_88a5c_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_c0698">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c0698_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_c0698_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_c0698_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_c0698_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_c0698_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_c0698_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0698_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c0698_row0_col0" class="data row0 col0" >0.1626</td>
#       <td id="T_c0698_row0_col1" class="data row0 col1" >226.7994</td>
#       <td id="T_c0698_row0_col2" class="data row0 col2" >1.6960</td>
#       <td id="T_c0698_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_c0698_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_c0698_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
_3clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/PCA/3clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_4clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/PCA/4clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_5clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/PCA/5clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='cluster')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_53.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='cluster')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_54.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='cluster')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_55.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
plot_model(_4clustermodel, plot='elbow')

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='silhouette')
# Out:
# For C = 3

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='silhouette')
# Out:
# For C = 4

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='silhouette')
# Out:
# For C = 5

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='distribution')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_60.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='distribution')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_61.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='distribution')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_62.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# <H3>K-Means Using Transformation+Normalization</H3>

# %%
setup(data = reviews, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

# %%
print("For Cluster = 3")
_3clustermodel = create_model('kmeans', num_clusters = 3)
_3clusterprediction = assign_model(_3clustermodel)

print("For Cluster = 4")
_4clustermodel = create_model('kmeans', num_clusters = 4)
_4clusterprediction = assign_model(_4clustermodel)

print("For Cluster = 5")
_5clustermodel = create_model('kmeans', num_clusters = 5)
_5clusterprediction = assign_model(_5clustermodel)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_776b8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_776b8_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_776b8_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_776b8_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_776b8_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_776b8_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_776b8_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_776b8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_776b8_row0_col0" class="data row0 col0" >0.1408</td>
#       <td id="T_776b8_row0_col1" class="data row0 col1" >197.8177</td>
#       <td id="T_776b8_row0_col2" class="data row0 col2" >2.1406</td>
#       <td id="T_776b8_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_776b8_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_776b8_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_3761f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3761f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_3761f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_3761f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_3761f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_3761f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_3761f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3761f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3761f_row0_col0" class="data row0 col0" >0.1350</td>
#       <td id="T_3761f_row0_col1" class="data row0 col1" >169.6014</td>
#       <td id="T_3761f_row0_col2" class="data row0 col2" >2.0276</td>
#       <td id="T_3761f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_3761f_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_3761f_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_f2e7a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2e7a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f2e7a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f2e7a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f2e7a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f2e7a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f2e7a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2e7a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f2e7a_row0_col0" class="data row0 col0" >0.1316</td>
#       <td id="T_f2e7a_row0_col1" class="data row0 col1" >145.0404</td>
#       <td id="T_f2e7a_row0_col2" class="data row0 col2" >2.0171</td>
#       <td id="T_f2e7a_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_f2e7a_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_f2e7a_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
_3clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/T+N/3clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_4clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/T+N/4clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_5clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/T+N/5clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='cluster')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_69.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='cluster')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_70.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='cluster')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_71.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
plot_model(_4clustermodel, plot='elbow')

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='silhouette')
# Out:
# For C = 3

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='silhouette')
# Out:
# For C = 4

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='silhouette')
# Out:
# For C = 5

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='distribution')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_76.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='distribution')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_77.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='distribution')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_78.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# <H3>K-Means Using Transformation + Normalization + PCA</H3>

# %%
setup(data = reviews, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)

# %%
print("For Cluster = 3")
_3clustermodel = create_model('kmeans', num_clusters = 3)
_3clusterprediction = assign_model(_3clustermodel)

print("For Cluster = 4")
_4clustermodel = create_model('kmeans', num_clusters = 4)
_4clusterprediction = assign_model(_4clustermodel)

print("For Cluster = 5")
_5clustermodel = create_model('kmeans', num_clusters = 5)
_5clusterprediction = assign_model(_5clustermodel)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_8f603">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8f603_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_8f603_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_8f603_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_8f603_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_8f603_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_8f603_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8f603_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8f603_row0_col0" class="data row0 col0" >0.1479</td>
#       <td id="T_8f603_row0_col1" class="data row0 col1" >203.3089</td>
#       <td id="T_8f603_row0_col2" class="data row0 col2" >2.1403</td>
#       <td id="T_8f603_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_8f603_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_8f603_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_3238b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3238b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_3238b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_3238b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_3238b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_3238b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_3238b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3238b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3238b_row0_col0" class="data row0 col0" >0.1288</td>
#       <td id="T_3238b_row0_col1" class="data row0 col1" >159.2820</td>
#       <td id="T_3238b_row0_col2" class="data row0 col2" >2.2098</td>
#       <td id="T_3238b_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_3238b_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_3238b_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_b7e5b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b7e5b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b7e5b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b7e5b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b7e5b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b7e5b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b7e5b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b7e5b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b7e5b_row0_col0" class="data row0 col0" >0.1313</td>
#       <td id="T_b7e5b_row0_col1" class="data row0 col1" >145.6176</td>
#       <td id="T_b7e5b_row0_col2" class="data row0 col2" >2.0376</td>
#       <td id="T_b7e5b_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_b7e5b_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_b7e5b_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
_3clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/T+N+P/3clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_4clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/T+N+P/4clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_5clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/T+N+P/5clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='cluster')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_84.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='cluster')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_85.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='cluster')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_86.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
plot_model(_4clustermodel, plot='elbow')

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='silhouette')
# Out:
# For C = 3

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='silhouette')
# Out:
# For C = 4

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='silhouette')
# Out:
# For C = 5

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='distribution')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_91.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='distribution')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_92.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='distribution')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_93.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
