# %%
import pandas as pd
from pycaret.clustering import *
import plotly.io as pio
pio.renderers.default = 'iframe'

# %%
reviews = pd.read_csv("tripadvisor_review.csv")
reviews.drop("User ID", axis = 1, inplace = True)
reviews
# Out:
#      Category 1  Category 2  Category 3  Category 4  Category 5  Category 6  \
# 0          0.93        1.80        2.29        0.62        0.80        2.42
# 1          1.02        2.20        2.66        0.64        1.42        3.18
# 2          1.22        0.80        0.54        0.53        0.24        1.54
# 3          0.45        1.80        0.29        0.57        0.46        1.52
# 4          0.51        1.20        1.18        0.57        1.54        2.02
# ..          ...         ...         ...         ...         ...         ...
# 975        0.74        1.12        0.30        0.53        0.88        1.38
# 976        1.25        0.92        1.12        0.38        0.78        1.68
# 977        0.61        1.32        0.67        0.43        1.30        1.78
# 978        0.93        0.20        0.13        0.43        0.30        0.40
# 979        0.93        0.56        1.13        0.51        1.34        2.36
#
#      Category 7  Category 8  Category 9  Category 10
# ...

# %%
ClusteringParameters = setup(reviews)
# Out:
# <style type="text/css">
# #T_ad544_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ad544">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ad544_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ad544_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad544_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ad544_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ad544_row0_col1" class="data row0 col1" >1694</td>
#     </tr>
#     <tr>
#       <th id="T_ad544_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ad544_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_ad544_row1_col1" class="data row1 col1" >(980, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_ad544_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %% [markdown]
# <H2>K-Means Clustering</H2>

# %% [markdown]
# <H3>K-Means Clustering Without Processing</H3>

# %%
print("For Cluster = 3")
_3clustermodel = create_model('kmeans', num_clusters = 3)
_3clusterprediction = assign_model(_3clustermodel)

print("For Cluster = 4")
_4clustermodel = create_model('kmeans', num_clusters = 4)
_4clusterprediction = assign_model(_4clustermodel)

print("For Cluster = 5")
_5clustermodel = create_model('kmeans', num_clusters = 5)
_5clusterprediction = assign_model(_5clustermodel)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_b9bad">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9bad_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b9bad_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b9bad_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b9bad_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b9bad_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b9bad_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9bad_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b9bad_row0_col0" class="data row0 col0" >0.1951</td>
#       <td id="T_b9bad_row0_col1" class="data row0 col1" >314.3555</td>
# ...

# %%
_3clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/No_Data_Processing/3clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_4clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/No_Data_Processing/4clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_5clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/No_Data_Processing/5clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='cluster')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_8.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='cluster')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_9.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='cluster')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_10.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
plot_model(_4clustermodel, plot='elbow')

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='silhouette')
# Out:
# For C = 3

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='silhouette')
# Out:
# For C = 4

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='silhouette')
# Out:
# For C = 5

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='distribution')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_15.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='distribution')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_16.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='distribution')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_17.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# <H3>K-Means Using Normalisation</H3>

# %%
ClusteringParameters = setup(data = reviews, normalize = True, normalize_method = 'zscore', verbose=False)

# %%
print("For Cluster = 3")
_3clustermodel = create_model('kmeans', num_clusters = 3)
_3clusterprediction = assign_model(_3clustermodel)

print("For Cluster = 4")
_4clustermodel = create_model('kmeans', num_clusters = 4)
_4clusterprediction = assign_model(_4clustermodel)

print("For Cluster = 5")
_5clustermodel = create_model('kmeans', num_clusters = 5)
_5clusterprediction = assign_model(_5clustermodel)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_6d94a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6d94a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6d94a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6d94a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6d94a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6d94a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6d94a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d94a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6d94a_row0_col0" class="data row0 col0" >0.1381</td>
#       <td id="T_6d94a_row0_col1" class="data row0 col1" >182.9848</td>
# ...

# %%
_3clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/Normalisation/3clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_4clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/Normalisation/4clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_5clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/Normalisation/5clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='cluster')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_23.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='cluster')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_24.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='cluster')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_25.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
plot_model(_4clustermodel, plot='elbow')

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='silhouette')
# Out:
# For C = 3

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='silhouette')
# Out:
# For C = 4

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='silhouette')
# Out:
# For C = 5

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='distribution')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_30.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='distribution')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_31.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='distribution')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_32.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# <H3>K-Means Using Transformation</H3>

# %%
setup(data = reviews, transformation = True, transformation_method = 'yeo-johnson', verbose=False)

# %%
print("For Cluster = 3")
_3clustermodel = create_model('kmeans', num_clusters = 3)
_3clusterprediction = assign_model(_3clustermodel)

print("For Cluster = 4")
_4clustermodel = create_model('kmeans', num_clusters = 4)
_4clusterprediction = assign_model(_4clustermodel)

print("For Cluster = 5")
_5clustermodel = create_model('kmeans', num_clusters = 5)
_5clusterprediction = assign_model(_5clustermodel)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_c4ba0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c4ba0_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_c4ba0_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_c4ba0_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_c4ba0_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_c4ba0_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_c4ba0_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c4ba0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c4ba0_row0_col0" class="data row0 col0" >0.2323</td>
#       <td id="T_c4ba0_row0_col1" class="data row0 col1" >426.4010</td>
# ...

# %%
_3clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/Transformation/3clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_4clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/Transformation/4clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_5clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/Transformation/5clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='cluster')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_38.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='cluster')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_39.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='cluster')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_40.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
plot_model(_4clustermodel, plot='elbow')

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='silhouette')
# Out:
# For C = 3

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='silhouette')
# Out:
# For C = 4

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='silhouette')
# Out:
# For C = 5

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='distribution')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_45.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='distribution')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_46.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='distribution')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_47.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# <H3>K-Means using PCA</H3>

# %%
setup(data = reviews, pca = True, pca_method = 'linear', verbose=False)

# %%
print("For Cluster = 3")
_3clustermodel = create_model('kmeans', num_clusters = 3)
_3clusterprediction = assign_model(_3clustermodel)

print("For Cluster = 4")
_4clustermodel = create_model('kmeans', num_clusters = 4)
_4clusterprediction = assign_model(_4clustermodel)

print("For Cluster = 5")
_5clustermodel = create_model('kmeans', num_clusters = 5)
_5clusterprediction = assign_model(_5clustermodel)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_5d29b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5d29b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5d29b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5d29b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5d29b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5d29b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5d29b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d29b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5d29b_row0_col0" class="data row0 col0" >0.1976</td>
#       <td id="T_5d29b_row0_col1" class="data row0 col1" >314.4115</td>
# ...

# %%
_3clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/PCA/3clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_4clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/PCA/4clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_5clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/PCA/5clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='cluster')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_53.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='cluster')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_54.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='cluster')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_55.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
plot_model(_4clustermodel, plot='elbow')

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='silhouette')
# Out:
# For C = 3

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='silhouette')
# Out:
# For C = 4

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='silhouette')
# Out:
# For C = 5

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='distribution')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_60.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='distribution')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_61.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='distribution')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_62.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# <H3>K-Means Using Transformation+Normalization</H3>

# %%
setup(data = reviews, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

# %%
print("For Cluster = 3")
_3clustermodel = create_model('kmeans', num_clusters = 3)
_3clusterprediction = assign_model(_3clustermodel)

print("For Cluster = 4")
_4clustermodel = create_model('kmeans', num_clusters = 4)
_4clusterprediction = assign_model(_4clustermodel)

print("For Cluster = 5")
_5clustermodel = create_model('kmeans', num_clusters = 5)
_5clusterprediction = assign_model(_5clustermodel)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_5ddc9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5ddc9_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5ddc9_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5ddc9_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5ddc9_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5ddc9_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5ddc9_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5ddc9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5ddc9_row0_col0" class="data row0 col0" >0.1479</td>
#       <td id="T_5ddc9_row0_col1" class="data row0 col1" >203.3090</td>
# ...

# %%
_3clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/T+N/3clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_4clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/T+N/4clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_5clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/T+N/5clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='cluster')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_68.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='cluster')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_69.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='cluster')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_70.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
plot_model(_4clustermodel, plot='elbow')

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='silhouette')
# Out:
# For C = 3

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='silhouette')
# Out:
# For C = 4

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='silhouette')
# Out:
# For C = 5

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='distribution')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_75.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='distribution')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_76.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='distribution')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_77.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# <H3>K-Means Using Transformation + Normalization + PCA</H3>

# %%
setup(data = reviews, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)

# %%
print("For Cluster = 3")
_3clustermodel = create_model('kmeans', num_clusters = 3)
_3clusterprediction = assign_model(_3clustermodel)

print("For Cluster = 4")
_4clustermodel = create_model('kmeans', num_clusters = 4)
_4clusterprediction = assign_model(_4clustermodel)

print("For Cluster = 5")
_5clustermodel = create_model('kmeans', num_clusters = 5)
_5clusterprediction = assign_model(_5clustermodel)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_9ce17">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9ce17_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9ce17_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9ce17_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9ce17_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9ce17_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9ce17_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ce17_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9ce17_row0_col0" class="data row0 col0" >0.1403</td>
#       <td id="T_9ce17_row0_col1" class="data row0 col1" >197.8235</td>
# ...

# %%
_3clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/T+N+P/3clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_4clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/T+N+P/4clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_5clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/kMeans/T+N+P/5clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='cluster')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_83.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='cluster')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_84.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='cluster')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_85.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
plot_model(_4clustermodel, plot='elbow')

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='silhouette')
# Out:
# For C = 3

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='silhouette')
# Out:
# For C = 4

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='silhouette')
# Out:
# For C = 5

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='distribution')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_90.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='distribution')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_91.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='distribution')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_92.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# <h2>Hierarchical Clustering</h2>

# %% [markdown]
# <h3>Hierarchical Clustering Without Processing</h3>

# %%
setup(reviews)
# Out:
# <style type="text/css">
# #T_8714e_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_8714e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8714e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_8714e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8714e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8714e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_8714e_row0_col1" class="data row0 col1" >6173</td>
#     </tr>
#     <tr>
#       <th id="T_8714e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8714e_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_8714e_row1_col1" class="data row1 col1" >(980, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_8714e_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
print("For Cluster = 3")
_3clustermodel = create_model('hclust', num_clusters = 3)
_3clusterprediction = assign_model(_3clustermodel)

print("For Cluster = 4")
_4clustermodel = create_model('hclust', num_clusters = 4)
_4clusterprediction = assign_model(_4clustermodel)

print("For Cluster = 5")
_5clustermodel = create_model('hclust', num_clusters = 5)
_5clusterprediction = assign_model(_5clustermodel)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_0ead0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0ead0_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_0ead0_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_0ead0_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_0ead0_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_0ead0_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_0ead0_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0ead0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0ead0_row0_col0" class="data row0 col0" >0.2187</td>
#       <td id="T_0ead0_row0_col1" class="data row0 col1" >263.4422</td>
# ...

# %%
_3clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/Hierarchical/No_Data_Processing/3clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_4clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/Hierarchical/No_Data_Processing/4clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_5clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/Hierarchical/No_Data_Processing/5clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='cluster')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_98.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='cluster')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_99.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='cluster')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_100.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
plot_model(_4clustermodel, plot='elbow')

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='distribution')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_102.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='distribution')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_103.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='distribution')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_104.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# <h3>Hierarchical Clustering Using Normalisation</h3>

# %%
ClusteringParameters = setup(data = reviews, normalize = True, normalize_method = 'zscore', verbose=False)

# %%
print("For Cluster = 3")
_3clustermodel = create_model('hclust', num_clusters = 3)
_3clusterprediction = assign_model(_3clustermodel)

print("For Cluster = 4")
_4clustermodel = create_model('hclust', num_clusters = 4)
_4clusterprediction = assign_model(_4clustermodel)

print("For Cluster = 5")
_5clustermodel = create_model('hclust', num_clusters = 5)
_5clusterprediction = assign_model(_5clustermodel)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_2aa07">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2aa07_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_2aa07_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_2aa07_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_2aa07_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_2aa07_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_2aa07_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2aa07_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2aa07_row0_col0" class="data row0 col0" >0.1847</td>
#       <td id="T_2aa07_row0_col1" class="data row0 col1" >156.1901</td>
# ...

# %%
_3clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/Hierarchical/Normalisation/3clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_4clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/Hierarchical/Normalisation/4clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_5clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/Hierarchical/Normalisation/5clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='cluster')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_110.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='cluster')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_111.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='cluster')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_112.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
plot_model(_4clustermodel, plot='elbow')

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='distribution')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_114.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='distribution')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_115.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='distribution')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_116.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# <h3>Hierarchical Clustering Using Transformation</h3>

# %%
setup(data = reviews, transformation = True, transformation_method = 'yeo-johnson', verbose=False)

# %%
print("For Cluster = 3")
_3clustermodel = create_model('hclust', num_clusters = 3)
_3clusterprediction = assign_model(_3clustermodel)

print("For Cluster = 4")
_4clustermodel = create_model('hclust', num_clusters = 4)
_4clusterprediction = assign_model(_4clustermodel)

print("For Cluster = 5")
_5clustermodel = create_model('hclust', num_clusters = 5)
_5clusterprediction = assign_model(_5clustermodel)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_cd51c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd51c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_cd51c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_cd51c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_cd51c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_cd51c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_cd51c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd51c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cd51c_row0_col0" class="data row0 col0" >0.2239</td>
#       <td id="T_cd51c_row0_col1" class="data row0 col1" >376.9295</td>
# ...

# %%
_3clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/Hierarchical/Transformation/3clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_4clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/Hierarchical/Transformation/4clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_5clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/Hierarchical/Transformation/5clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='cluster')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_122.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='cluster')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_123.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='cluster')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_124.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
plot_model(_4clustermodel, plot='elbow')

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='distribution')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_126.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='distribution')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_127.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='distribution')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_128.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# <h3>Hierarchical Clustering using PCA</h3>

# %%
setup(data = reviews, pca = True, pca_method = 'linear', verbose=False)

# %%
print("For Cluster = 3")
_3clustermodel = create_model('hclust', num_clusters = 3)
_3clusterprediction = assign_model(_3clustermodel)

print("For Cluster = 4")
_4clustermodel = create_model('hclust', num_clusters = 4)
_4clusterprediction = assign_model(_4clustermodel)

print("For Cluster = 5")
_5clustermodel = create_model('hclust', num_clusters = 5)
_5clusterprediction = assign_model(_5clustermodel)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_3b485">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3b485_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_3b485_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_3b485_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_3b485_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_3b485_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_3b485_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b485_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3b485_row0_col0" class="data row0 col0" >0.2187</td>
#       <td id="T_3b485_row0_col1" class="data row0 col1" >263.4422</td>
# ...

# %%
_3clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/Hierarchical/PCA/3clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_4clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/Hierarchical/PCA/4clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_5clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/Hierarchical/PCA/5clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='cluster')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_134.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='cluster')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_135.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='cluster')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_136.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
plot_model(_4clustermodel, plot='elbow')

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='distribution')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_138.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='distribution')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_139.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='distribution')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_140.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# <h3>Hierarchical Clustering Using Transformation+Normalization</h3>

# %%
setup(data = reviews, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

# %%
print("For Cluster = 3")
_3clustermodel = create_model('hclust', num_clusters = 3)
_3clusterprediction = assign_model(_3clustermodel)

print("For Cluster = 4")
_4clustermodel = create_model('hclust', num_clusters = 4)
_4clusterprediction = assign_model(_4clustermodel)

print("For Cluster = 5")
_5clustermodel = create_model('hclust', num_clusters = 5)
_5clusterprediction = assign_model(_5clustermodel)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_f8b5c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8b5c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f8b5c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f8b5c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f8b5c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f8b5c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f8b5c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8b5c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f8b5c_row0_col0" class="data row0 col0" >0.1217</td>
#       <td id="T_f8b5c_row0_col1" class="data row0 col1" >168.6436</td>
# ...

# %%
_3clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/Hierarchical/T+N/3clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_4clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/Hierarchical/T+N/4clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_5clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/Hierarchical/T+N/5clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='cluster')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_146.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='cluster')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_147.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='cluster')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_148.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
plot_model(_4clustermodel, plot='elbow')

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='distribution')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_150.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='distribution')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_151.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='distribution')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_152.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# <h3>Hierarchical Clustering Using Transformation + Normalization + PCA</h3>

# %%
setup(data = reviews, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)

# %%
print("For Cluster = 3")
_3clustermodel = create_model('hclust', num_clusters = 3)
_3clusterprediction = assign_model(_3clustermodel)

print("For Cluster = 4")
_4clustermodel = create_model('hclust', num_clusters = 4)
_4clusterprediction = assign_model(_4clustermodel)

print("For Cluster = 5")
_5clustermodel = create_model('hclust', num_clusters = 5)
_5clusterprediction = assign_model(_5clustermodel)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_13f16">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13f16_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_13f16_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_13f16_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_13f16_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_13f16_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_13f16_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13f16_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_13f16_row0_col0" class="data row0 col0" >0.1217</td>
#       <td id="T_13f16_row0_col1" class="data row0 col1" >168.6436</td>
# ...

# %%
_3clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/Hierarchical/T+N+P/3clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_4clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/Hierarchical/T+N+P/4clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
_5clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/Hierarchical/T+N+P/5clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='cluster')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_158.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='cluster')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_159.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='cluster')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_160.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
plot_model(_4clustermodel, plot='elbow')

# %%
print("For C = 3")
plot_model(_3clustermodel, plot='distribution')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_162.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 4")
plot_model(_4clustermodel, plot='distribution')
# Out:
# For C = 4
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_163.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 5")
plot_model(_5clustermodel, plot='distribution')
# Out:
# For C = 5
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_164.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# <H2>Mean Shift Clustering</H2>

# %% [markdown]
# <h3>Mean Shift Clustering Without Processing</h3>

# %%
ClusteringParameters = setup(reviews)
# Out:
# <style type="text/css">
# #T_e2edb_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e2edb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2edb_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e2edb_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2edb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e2edb_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e2edb_row0_col1" class="data row0 col1" >8586</td>
#     </tr>
#     <tr>
#       <th id="T_e2edb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e2edb_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_e2edb_row1_col1" class="data row1 col1" >(980, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_e2edb_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
clustermodel = create_model('meanshift')
clusterprediction = assign_model(clustermodel)
# Out:
# <style type="text/css">
# </style>
# <table id="T_41ed6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41ed6_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_41ed6_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_41ed6_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_41ed6_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_41ed6_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_41ed6_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41ed6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_41ed6_row0_col0" class="data row0 col0" >0.1940</td>
#       <td id="T_41ed6_row0_col1" class="data row0 col1" >38.7240</td>
#       <td id="T_41ed6_row0_col2" class="data row0 col2" >1.1312</td>
# ...

# %%
clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/meanshift/No_Data_Processing/clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
plot_model(clustermodel, plot='cluster')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_168.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
plot_model(clustermodel, plot='distribution')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_169.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# <H3>Mean Shift Clustering Using Normalisation</H3>

# %%
ClusteringParameters = setup(data = reviews, normalize = True, normalize_method = 'zscore', verbose=False)

# %%
clustermodel = create_model('meanshift')
clusterprediction = assign_model(clustermodel)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5f13f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f13f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5f13f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5f13f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5f13f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5f13f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5f13f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f13f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5f13f_row0_col0" class="data row0 col0" >0.2710</td>
#       <td id="T_5f13f_row0_col1" class="data row0 col1" >24.2104</td>
#       <td id="T_5f13f_row0_col2" class="data row0 col2" >1.1152</td>
# ...

# %%
clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/meanshift/Normalisation/clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
plot_model(clustermodel, plot='cluster')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_173.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
plot_model(clustermodel, plot='distribution')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_174.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# <H3>Mean Shift Clustering Using Transformation</H3>

# %%
setup(data = reviews, transformation = True, transformation_method = 'yeo-johnson', verbose=False)

# %%
clustermodel = create_model('meanshift')
clusterprediction = assign_model(clustermodel)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ac756">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ac756_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_ac756_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_ac756_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_ac756_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_ac756_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_ac756_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac756_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ac756_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_ac756_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_ac756_row0_col2" class="data row0 col2" >0</td>
# ...

# %%
clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/meanshift/Transformation/clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
plot_model(clustermodel, plot='cluster')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_178.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
plot_model(clustermodel, plot='distribution')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_179.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# <H3>Mean Shift Clustering using PCA</H3>

# %%
setup(data = reviews, pca = True, pca_method = 'linear', verbose=False)

# %%
clustermodel = create_model('meanshift')
clusterprediction = assign_model(clustermodel)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2b603">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b603_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_2b603_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_2b603_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_2b603_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_2b603_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_2b603_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b603_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2b603_row0_col0" class="data row0 col0" >0.1940</td>
#       <td id="T_2b603_row0_col1" class="data row0 col1" >38.7240</td>
#       <td id="T_2b603_row0_col2" class="data row0 col2" >1.1312</td>
# ...

# %%
clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/meanshift/PCA/clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
plot_model(clustermodel, plot='cluster')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_183.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
plot_model(clustermodel, plot='distribution')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_184.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# <H3>Mean Shift Clustering Using Transformation+Normalization</H3>

# %%
setup(data = reviews, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

# %%
clustermodel = create_model('meanshift')
clusterprediction = assign_model(clustermodel)
# Out:
# <style type="text/css">
# </style>
# <table id="T_64db2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64db2_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_64db2_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_64db2_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_64db2_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_64db2_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_64db2_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64db2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_64db2_row0_col0" class="data row0 col0" >0.2836</td>
#       <td id="T_64db2_row0_col1" class="data row0 col1" >13.4662</td>
#       <td id="T_64db2_row0_col2" class="data row0 col2" >1.0082</td>
# ...

# %%
clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/meanshift/T+N/clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
plot_model(clustermodel, plot='cluster')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_188.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
print("For C = 3")
plot_model(clustermodel, plot='distribution')
# Out:
# For C = 3
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_190.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# <H3>Mean Shift Clustering Using Transformation + Normalization + PCA</H3>

# %%
setup(data = reviews, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)

# %%
clustermodel = create_model('meanshift')
clusterprediction = assign_model(clustermodel)
# Out:
# <style type="text/css">
# </style>
# <table id="T_29f0b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_29f0b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_29f0b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_29f0b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_29f0b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_29f0b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_29f0b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29f0b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_29f0b_row0_col0" class="data row0 col0" >0.2836</td>
#       <td id="T_29f0b_row0_col1" class="data row0 col1" >13.4662</td>
#       <td id="T_29f0b_row0_col2" class="data row0 col2" >1.0082</td>
# ...

# %%
clusterprediction.to_csv("C:/Users/MOKSH/OneDrive/Desktop/ML lab/clustering/meanshift/T+N+P/clusterResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
plot_model(clustermodel, plot='cluster')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_195.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
plot_model(clustermodel, plot='distribution')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="620"
#     src="iframe_figures/figure_196.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
